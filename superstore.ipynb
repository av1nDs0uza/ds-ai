# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('superstore_data.csv')

# %%
print(df)
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 0            0   6/16/2014        0       189  ...              111
# ...

# %% [markdown]
# # 1. Display range of columns

# %%
print(df.columns)
# Out:
# Index(['Id', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'Response', 'Complain'],
#       dtype='object')

# %% [markdown]
# # 2. Display range of rows

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=2240, step=1)

# %% [markdown]
# # 3. Display column 1 to 4

# %%
print(df.iloc[:,:4])
# Out:
#          Id  Year_Birth   Education Marital_Status
# 0      1826        1970  Graduation       Divorced
# 1         1        1961  Graduation         Single
# 2     10476        1958  Graduation        Married
# 3      1386        1967  Graduation       Together
# 4      5371        1989  Graduation         Single
# ...     ...         ...         ...            ...
# 2235  10142        1976         PhD       Divorced
# 2236   5263        1977    2n Cycle        Married
# 2237     22        1976  Graduation       Divorced
# 2238    528        1978  Graduation        Married
# 2239   4070        1969         PhD        Married
#
# [2240 rows x 4 columns]

# %% [markdown]
# # 4. Display row 2 to 4

# %%
print(df.iloc[2:4])
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
#
#    MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# 2            30                  1                3                    2
# 3             0                  1                1                    0
#
#    NumStorePurchases  NumWebVisitsMonth  Response  Complain
# 2                  5                  2         0         0
# 3                  2                  7         0         0
#
# [2 rows x 22 columns]

# %% [markdown]
# # 6. Access all rows and 1 column

# %%
print(df.iloc[0])
# Out:
# Id                           1826
# Year_Birth                   1970
# Education              Graduation
# Marital_Status           Divorced
# Income                    84835.0
# Kidhome                         0
# Teenhome                        0
# Dt_Customer             6/16/2014
# Recency                         0
# MntWines                      189
# MntFruits                     104
# MntMeatProducts               379
# MntFishProducts               111
# MntSweetProducts              189
# MntGoldProds                  218
# NumDealsPurchases               1
# NumWebPurchases                 4
# NumCatalogPurchases             4
# NumStorePurchases               6
# NumWebVisitsMonth               1
# Response                        1
# Complain                        0
# Name: 0, dtype: object

# %% [markdown]
# # 5. Access 1 row and all columns

# %%
print(df["Id"])
# Out:
# 0        1826
# 1           1
# 2       10476
# 3        1386
# 4        5371
#         ...
# 2235    10142
# 2236     5263
# 2237       22
# 2238      528
# 2239     4070
# Name: Id, Length: 2240, dtype: int64

# %% [markdown]
# # 7. Select row by label

# %%
print(df.iloc[1:0:,3]))
# Out:
#   Input In [47]
#     print(df.iloc[1:0:,3]))
#                           ^
# SyntaxError: unmatched ')'

# %% [markdown]
# # 8. Select column by label

# %%
print(df.filter(items=['Year_Birth']))
# Out:
#       Year_Birth
# 0           1970
# 1           1961
# 2           1958
# 3           1967
# 4           1989
# ...          ...
# 2235        1976
# 2236        1977
# 2237        1976
# 2238        1978
# 2239        1969
#
# [2240 rows x 1 columns]

# %% [markdown]
# # 22. Draw a graph using matplotlib for any dataframe

# %% [markdown]
# ## a. draw a bar graph

# %%
df.plot(x="Education", y="Income", kind="bar")
# Out:
# <AxesSubplot:xlabel='Education'>

# %% [markdown]
# ## c. Draw a histogram

# %%
df.plot(x="Education", y="Income", kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ## e. Draw a scatter

# %%
df.plot(x="Education", y="Income", kind="scatter")
# Out:
# <AxesSubplot:xlabel='Education', ylabel='Income'>

# %% [markdown]
# ## g. Draw a pairplot

# %%
g= pd.plotting.scatter_matrix(df, figsize=(10,10), marker = 'o', hist_kwds = {'bins': 10}, s = 60, alpha = 0.8)
plt.show()

# %% [markdown]
# ## h. draw relation

# %%
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\avsaa\OneDrive\Desktop\ds & ai\superstore.ipynb Cell 30 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/avsaa/OneDrive/Desktop/ds%20%26%20ai/superstore.ipynb#X45sZmlsZQ%3D%3D?line=0'>1</a> df.plot(x="Education", y="Income", kind="relation")
#
# File c:\Python310\lib\site-packages\pandas\plotting\_core.py:905, in PlotAccessor.__call__(self, *args, **kwargs)
#     902     return plot_backend.plot(self._parent, x=x, y=y, kind=kind, **kwargs)
#     904 if kind not in self._all_kinds:
# --> 905     raise ValueError(f"{kind} is not a valid plot kind")
#     907 # The original data structured can be transformed before passed to the
#     908 # backend. For example, for DataFrame is common to set the index as the
#     909 # `x` parameter, and return a Series with the parameter `y` as values.
# ...

# %% [markdown]
# ## i. draw boxplot

# %%
df.plot(x="Education", y="Income", kind="box")
# Out:
# <AxesSubplot:>
